# %% [markdown]
# ## Load Libraries

# %% [markdown]
# # Advance Pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ny_weather.csv')
df.head()
# Out:
#        Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016         38.0      23.0      52.0                 30.03
# 1  1/2/2016         36.0      18.0      46.0                 30.02
# 2  1/3/2016          NaN       NaN      47.0                 29.86
# 3  1/6/2016         33.0       NaN      35.0                   NaN
# 4  1/7/2016         39.0      11.0      33.0                 30.28
#
#    VisibilityMiles  WindSpeedMPH   Event
# 0             10.0           8.0    Rain
# 1             10.0           7.0   Sunny
# 2             10.0           8.0    Snow
# 3             10.0           4.0    Rain
# 4             10.0           2.0  Cloudy

# %% [markdown]
# ## Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  14 non-null     object
#  1   Temperature           11 non-null     float64
#  2   DewPoint              11 non-null     float64
#  3   Humidity              11 non-null     float64
#  4   Sea Level PressureIn  11 non-null     float64
#  5   VisibilityMiles       12 non-null     float64
#  6   WindSpeedMPH          10 non-null     float64
#  7   Event                 11 non-null     object
# dtypes: float64(6), object(2)
# memory usage: 1.0+ KB

# %%
df.shape
# Out:
# (14, 8)

# %%
df.isnull().sum()/len(df) *100
# Out:
# Date                     0.000000
# Temperature             21.428571
# DewPoint                21.428571
# Humidity                21.428571
# Sea Level PressureIn    21.428571
# VisibilityMiles         14.285714
# WindSpeedMPH            28.571429
# Event                   21.428571
# dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'Event'],
#       dtype='object')

# %%
df['Temperature'] = df['Temperature'].fillna(df['Temperature'].mode()[0])
df['DewPoint'] = df['DewPoint'].fillna(df['DewPoint'].mean())
df['Humidity'] = df['Humidity'].fillna(df['Humidity'].median())
df['Sea Level PressureIn'] = df['Sea Level PressureIn'].fillna(df["Sea Level PressureIn"].mean())
df['VisibilityMiles'] = df['VisibilityMiles'].fillna(df['VisibilityMiles'].median())
df['WindSpeedMPH'] = df['WindSpeedMPH'].fillna(df['WindSpeedMPH'].median())
df['Event'] = df['Event'].fillna(df['Event'].mode()[0])

# %%
df["Event"].unique()
# Out:
# array(['Rain', 'Sunny', 'Snow', 'Cloudy', nan], dtype=object)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## Slicing using loc and iloc
# - loc - Access through columns name
# - iloc - Access through columns index

# %%
df.loc[6:9,["Temperature","Humidity","Event"]]
# Out:
#    Temperature  Humidity Event
# 6         44.0      77.0   NaN
# 7          NaN       NaN  Snow
# 8         33.0      37.0   NaN
# 9         35.0      53.0   NaN

# %%
df.columns
# Out:
# Index(['Date', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'Event'],
#       dtype='object')

# %%
df.iloc[6:9, [1,3,7]]
# Out:
#    Temperature  Humidity Event
# 6         44.0      77.0   NaN
# 7          NaN       NaN  Snow
# 8         33.0      37.0   NaN

# %%
df.iloc[6:9,:]
# Out:
#         Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 6   1/9/2016         44.0      38.0      77.0                 30.16
# 7  1/10/2016          NaN      46.0       NaN                   NaN
# 8  1/11/2016         33.0       8.0      37.0                 29.92
#
#    VisibilityMiles  WindSpeedMPH Event
# 6              NaN           8.0   NaN
# 7              4.0           NaN  Snow
# 8             10.0           NaN   NaN

# %%
df.loc[:,['Temperature', 'Humidity','VisibilityMiles','WindSpeedMPH', 'Event']]
# Out:
#     Temperature  Humidity  VisibilityMiles  WindSpeedMPH   Event
# 0          38.0      52.0             10.0           8.0    Rain
# 1          36.0      46.0             10.0           7.0   Sunny
# 2           NaN      47.0             10.0           8.0    Snow
# 3          33.0      35.0             10.0           4.0    Rain
# 4          39.0      33.0             10.0           2.0  Cloudy
# 5          39.0       NaN             10.0           4.0   Sunny
# 6          44.0      77.0              NaN           8.0     NaN
# 7           NaN       NaN              4.0           NaN    Snow
# 8          33.0      37.0             10.0           NaN     NaN
# 9          35.0      53.0             10.0           6.0     NaN
# 10         26.0       NaN             10.0          10.0    Rain
# 11          NaN      47.0              NaN           NaN    Rain
# 12         36.0      66.0              8.0           6.0    Snow
# 13         25.0      53.0              9.0           NaN   Sunny

# %%
df[df['Humidity']>50]
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# 13  1/18/2016         25.0       6.0      53.0                 29.83
#
#     VisibilityMiles  WindSpeedMPH  Event
# 0              10.0           8.0   Rain
# 6               NaN           8.0    NaN
# 9              10.0           6.0    NaN
# 12              8.0           6.0   Snow
# 13              9.0           NaN  Sunny

# %%
df.at[12,"Event"]
# Out:
# 'Snow'

# %% [markdown]
# ## Add a new column in Dataset
# - with arange (  )
# - with random (  )

# %%
values = np.arange(30,44)
len(values)
# Out:
# 14

# %%
df["New_column"] = values
df.head()
# Out:
#        Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016         38.0      23.0      52.0                 30.03
# 1  1/2/2016         36.0      18.0      46.0                 30.02
# 2  1/3/2016          NaN       NaN      47.0                 29.86
# 3  1/6/2016         33.0       NaN      35.0                   NaN
# 4  1/7/2016         39.0      11.0      33.0                 30.28
#
#    VisibilityMiles  WindSpeedMPH   Event  New_column
# 0             10.0           8.0    Rain          30
# 1             10.0           7.0   Sunny          31
# 2             10.0           8.0    Snow          32
# 3             10.0           4.0    Rain          33
# 4             10.0           2.0  Cloudy          34

# %%
df.shape
# Out:
# (14, 8)

# %%
rand_values = np.random.rand(14)

# %%
df['rand_values'] = rand_values
df.head()
# Out:
#        Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016         38.0      23.0      52.0                 30.03
# 1  1/2/2016         36.0      18.0      46.0                 30.02
# 2  1/3/2016          NaN       NaN      47.0                 29.86
# 3  1/6/2016         33.0       NaN      35.0                   NaN
# 4  1/7/2016         39.0      11.0      33.0                 30.28
#
#    VisibilityMiles  WindSpeedMPH   Event  New_column  rand_values
# 0             10.0           8.0    Rain          30     0.768113
# 1             10.0           7.0   Sunny          31     0.387567
# 2             10.0           8.0    Snow          32     0.971963
# 3             10.0           4.0    Rain          33     0.205523
# 4             10.0           2.0  Cloudy          34     0.190911

# %%
df['rand_values']
# Out:
# 0     0.768113
# 1     0.387567
# 2     0.971963
# 3     0.205523
# 4     0.190911
# 5     0.719201
# 6     0.264922
# 7     0.284818
# 8     0.814547
# 9     0.319235
# 10    0.501915
# 11    0.390553
# 12    0.064646
# 13    0.635997
# Name: rand_values, dtype: float64

# %%
df.drop(["New_column","rand_values"] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#        Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016         38.0      23.0      52.0                 30.03
# 1  1/2/2016         36.0      18.0      46.0                 30.02
# 2  1/3/2016          NaN       NaN      47.0                 29.86
# 3  1/6/2016         33.0       NaN      35.0                   NaN
# 4  1/7/2016         39.0      11.0      33.0                 30.28
#
#    VisibilityMiles  WindSpeedMPH   Event
# 0             10.0           8.0    Rain
# 1             10.0           7.0   Sunny
# 2             10.0           8.0    Snow
# 3             10.0           4.0    Rain
# 4             10.0           2.0  Cloudy

# %% [markdown]
# ## Add a new Record

# %%
df.loc[15] = ["1/1/2025", 39 , 25 , 52 , 34 , 8 , 9 , "Pleasent"]

# %%
df
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 1    1/2/2016         36.0      18.0      46.0                 30.02
# 2    1/3/2016          NaN       NaN      47.0                 29.86
# 3    1/6/2016         33.0       NaN      35.0                   NaN
# 4    1/7/2016         39.0      11.0      33.0                 30.28
# 5    1/8/2016         39.0      29.0       NaN                 30.20
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 7   1/10/2016          NaN      46.0       NaN                   NaN
# 8   1/11/2016         33.0       8.0      37.0                 29.92
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 10  1/13/2016         26.0       4.0       NaN                 29.94
# 11  1/14/2016          NaN      12.0      47.0                   NaN
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# 13  1/18/2016         25.0       6.0      53.0                 29.83
# 14   1/1/2018         39.0      25.0      52.0                 34.00
# 15   1/1/2025         39.0      25.0      52.0                 34.00
#
#     VisibilityMiles  WindSpeedMPH     Event
# 0              10.0           8.0      Rain
# 1              10.0           7.0     Sunny
# 2              10.0           8.0      Snow
# 3              10.0           4.0      Rain
# 4              10.0           2.0    Cloudy
# 5              10.0           4.0     Sunny
# 6               NaN           8.0       NaN
# 7               4.0           NaN      Snow
# 8              10.0           NaN       NaN
# 9              10.0           6.0       NaN
# 10             10.0          10.0      Rain
# 11              NaN           NaN      Rain
# 12              8.0           6.0      Snow
# 13              9.0           NaN     Sunny
# 14              8.0           9.0     Sunny
# 15              8.0           9.0  Pleasent

# %% [markdown]
# ## Drop records from 8 and 13

# %%
df.drop([8,13], inplace = True)
display(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.drop([8,13], inplace = True)
#       2 display(df)
#
# File c:\Users\Sobia Alamgir\miniconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\Sobia Alamgir\miniconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\Sobia Alamgir\miniconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\Sobia Alamgir\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[8, 13] not found in axis'

# %%
df
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 1    1/2/2016         36.0      18.0      46.0                 30.02
# 2    1/3/2016          NaN       NaN      47.0                 29.86
# 3    1/6/2016         33.0       NaN      35.0                   NaN
# 4    1/7/2016         39.0      11.0      33.0                 30.28
# 5    1/8/2016         39.0      29.0       NaN                 30.20
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 7   1/10/2016          NaN      46.0       NaN                   NaN
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 10  1/13/2016         26.0       4.0       NaN                 29.94
# 11  1/14/2016          NaN      12.0      47.0                   NaN
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# 14   1/1/2018         39.0      25.0      52.0                 34.00
# 15   1/1/2025         39.0      25.0      52.0                 34.00
#
#     VisibilityMiles  WindSpeedMPH     Event
# 0              10.0           8.0      Rain
# 1              10.0           7.0     Sunny
# 2              10.0           8.0      Snow
# 3              10.0           4.0      Rain
# 4              10.0           2.0    Cloudy
# 5              10.0           4.0     Sunny
# 6               NaN           8.0       NaN
# 7               4.0           NaN      Snow
# 9              10.0           6.0       NaN
# 10             10.0          10.0      Rain
# 11              NaN           NaN      Rain
# 12              8.0           6.0      Snow
# 14              8.0           9.0     Sunny
# 15              8.0           9.0  Pleasent

# %%
df.set_index("Date")
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 1/1/2016          38.0      23.0      52.0                 30.03
# 1/2/2016          36.0      18.0      46.0                 30.02
# 1/3/2016           NaN       NaN      47.0                 29.86
# 1/6/2016          33.0       NaN      35.0                   NaN
# 1/7/2016          39.0      11.0      33.0                 30.28
# 1/8/2016          39.0      29.0       NaN                 30.20
# 1/9/2016          44.0      38.0      77.0                 30.16
# 1/10/2016          NaN      46.0       NaN                   NaN
# 1/12/2016         35.0       NaN      53.0                 29.85
# 1/13/2016         26.0       4.0       NaN                 29.94
# 1/14/2016          NaN      12.0      47.0                   NaN
# 1/17/2016         36.0      23.0      66.0                 29.78
# 1/1/2018          39.0      25.0      52.0                 34.00
# 1/1/2025          39.0      25.0      52.0                 34.00
#
#            VisibilityMiles  WindSpeedMPH     Event
# Date
# 1/1/2016              10.0           8.0      Rain
# 1/2/2016              10.0           7.0     Sunny
# 1/3/2016              10.0           8.0      Snow
# 1/6/2016              10.0           4.0      Rain
# 1/7/2016              10.0           2.0    Cloudy
# 1/8/2016              10.0           4.0     Sunny
# 1/9/2016               NaN           8.0       NaN
# 1/10/2016              4.0           NaN      Snow
# 1/12/2016             10.0           6.0       NaN
# 1/13/2016             10.0          10.0      Rain
# 1/14/2016              NaN           NaN      Rain
# 1/17/2016              8.0           6.0      Snow
# 1/1/2018               8.0           9.0     Sunny
# 1/1/2025               8.0           9.0  Pleasent

# %%
df
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 1    1/2/2016         36.0      18.0      46.0                 30.02
# 2    1/3/2016          NaN       NaN      47.0                 29.86
# 3    1/6/2016         33.0       NaN      35.0                   NaN
# 4    1/7/2016         39.0      11.0      33.0                 30.28
# 5    1/8/2016         39.0      29.0       NaN                 30.20
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 7   1/10/2016          NaN      46.0       NaN                   NaN
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 10  1/13/2016         26.0       4.0       NaN                 29.94
# 11  1/14/2016          NaN      12.0      47.0                   NaN
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# 14   1/1/2018         39.0      25.0      52.0                 34.00
# 15   1/1/2025         39.0      25.0      52.0                 34.00
#
#     VisibilityMiles  WindSpeedMPH     Event
# 0              10.0           8.0      Rain
# 1              10.0           7.0     Sunny
# 2              10.0           8.0      Snow
# 3              10.0           4.0      Rain
# 4              10.0           2.0    Cloudy
# 5              10.0           4.0     Sunny
# 6               NaN           8.0       NaN
# 7               4.0           NaN      Snow
# 9              10.0           6.0       NaN
# 10             10.0          10.0      Rain
# 11              NaN           NaN      Rain
# 12              8.0           6.0      Snow
# 14              8.0           9.0     Sunny
# 15              8.0           9.0  Pleasent

# %%
df.columns
# Out:
# Index(['Date', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'Event'],
#       dtype='object')

# %%
df.mean(numeric_only = True)
# Out:
# Temperature             36.727273
# DewPoint                23.090909
# Humidity                50.909091
# Sea Level PressureIn    30.738182
# VisibilityMiles          9.000000
# WindSpeedMPH             6.750000
# dtype: float64

# %%
df.fillna({"rand_values":36.5 , "DewPoint": 23.09 , "Humidity": 50.9 , "Sea Level PressureIn":30.74 , 
"VisibilityMiles": 9 , "WindSpeedMPH": 6.75}, inplace = True)

# %%
df.shape
# Out:
# (14, 8)

# %%
df.dropna(inplace = True)
display(df)
print(df.shape)
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0     23.00      52.0                 30.03
# 1    1/2/2016         36.0     18.00      46.0                 30.02
# 3    1/6/2016         33.0     23.09      35.0                 30.74
# 4    1/7/2016         39.0     11.00      33.0                 30.28
# 5    1/8/2016         39.0     29.00      50.9                 30.20
# 10  1/13/2016         26.0      4.00      50.9                 29.94
# 12  1/17/2016         36.0     23.00      66.0                 29.78
# 13  1/18/2016         25.0      6.00      53.0                 29.83
#
#     VisibilityMiles  WindSpeedMPH   Event
# 0              10.0          8.00    Rain
# 1              10.0          7.00   Sunny
# 3              10.0          4.00    Rain
# 4              10.0          2.00  Cloudy
# 5              10.0          4.00   Sunny
# 10             10.0         10.00    Rain
# 12              8.0          6.00    Snow
# 13              9.0          6.75   Sunny
# (8, 8)

# %% [markdown]
# ## Group By in Pandas
# - Group my data by a specific column, then apply a calculation to each group.
# - It’s like creating mini-datasets inside your dataset — one for each unique value — and doing something with them (sum, mean, count, etc.)

# %%
df = df.groupby("Event")[["Temperature"]].mean()
df
# Out:
#         Temperature
# Event
# Cloudy    39.000000
# Rain      32.333333
# Snow      36.000000
# Sunny     33.333333

# %%
df.to_csv("Group_by_Event_Temp.csv" , index = False)

# %%
df_events = pd.read_csv("Group_by_Event_Temp.csv")
df_events.head()
# Out:
#    Temperature
# 0    39.000000
# 1    32.333333
# 2    36.000000
# 3    33.333333

# %%
col = df.columns.tolist()
col
# Out:
# ['Date',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'Event']

# %%
df
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 1    1/2/2016         36.0      18.0      46.0                 30.02
# 2    1/3/2016          NaN       NaN      47.0                 29.86
# 3    1/6/2016         33.0       NaN      35.0                   NaN
# 4    1/7/2016         39.0      11.0      33.0                 30.28
# 5    1/8/2016         39.0      29.0       NaN                 30.20
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 7   1/10/2016          NaN      46.0       NaN                   NaN
# 8   1/11/2016         33.0       8.0      37.0                 29.92
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 10  1/13/2016         26.0       4.0       NaN                 29.94
# 11  1/14/2016          NaN      12.0      47.0                   NaN
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# 13  1/18/2016         25.0       6.0      53.0                 29.83
#
#     VisibilityMiles  WindSpeedMPH   Event
# 0              10.0           8.0    Rain
# 1              10.0           7.0   Sunny
# 2              10.0           8.0    Snow
# 3              10.0           4.0    Rain
# 4              10.0           2.0  Cloudy
# 5              10.0           4.0   Sunny
# 6               NaN           8.0     NaN
# 7               4.0           NaN    Snow
# 8              10.0           NaN     NaN
# 9              10.0           6.0     NaN
# 10             10.0          10.0    Rain
# 11              NaN           NaN    Rain
# 12              8.0           6.0    Snow
# 13              9.0           NaN   Sunny

# %%
df.groupby('Event')[['Temperature','Humidity','DewPoint']].count()
# Out:
#         Temperature  Humidity  DewPoint
# Event
# Cloudy            1         1         1
# Rain              3         3         3
# Snow              1         2         2
# Sunny             3         2         3
