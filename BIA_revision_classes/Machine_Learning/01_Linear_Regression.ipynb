# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: SOBIA ALAMGIR</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/sobiahashmi)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.linkedin.com/in/sobia-alamgir-a027b939/)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/sobia-alamgir-a027b939/)
#
#
#
# <!-- [![Streamlit](https://img.shields.io/badge/Streamlit-Open%20App-FF4B4B?style=for-the-badge&logo=streamlit&logoColor=white)](https://predict-podcast-listening-time-fgkp77kmvwwpruyistfzhj.streamlit.app/) -->

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Linear Regression on Synthetic Dataset</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>

# %% [markdown]
# - Linear Regression is a supervised machine learning algorithm used to predict a numeric value (output) based on one or more input variables (features), by finding the best-fitting straight line through the data.
#
# - Formula :  Y = mX + b

# %% [markdown]
# | Symbol | Meaning                            |
# | ------ | ---------------------------------- |
# | Y      | Predicted value (target)           |
# | X      | Input value (feature)              |
# | m      | Slope of the line                  |
# | b      | Intercept (where line hits Y-axis) |

# %% [markdown]
# | Type           | Description                                                       |
# | -------------- | ----------------------------------------------------------------- |
# | **Simple**     | One feature (X) and one target (Y)                                |
# | **Multiple**   | Multiple features (X₁, X₂, X₃...) and one target (Y)              |
# | **Polynomial** | Not a straight line but curved — still based on linear principles |

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
#
# - [Step-01 Load Libraries](#toc2_)
# - [Step-02 Data Preparation](#toc3_)
# - [Step-03 Splitting the data](#toc4_)
# - [Step-04 Model Selection](#toc5_)
# - [Step-05 Model Prediction](#toc6_)
# - [Step-06 Model Evaluation](#toc7_)
# - [Step-07 Create Dataframe](#toc8_)
# - [Step-09 Data Visualization](#toc9_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc2_'></a>[Step-01 Load Libraries](#toc0_)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # <a id='toc3_'></a>[Step-02 Data Preparation](#toc0_)

# %%
np.random.seed(0)
hours_studied = np.random.uniform(0,10,100)
exam_scores = 50 + 5*hours_studied + np.random.normal(0,2,100)

# %%
print(f"Hours_studies: {len(hours_studied)}")
print(f"exam_scores: {len(exam_scores)}")
# Out:
# Hours_studies: 100
# exam_scores: 100

# %%
df = pd.DataFrame({"Hours_studied":hours_studied , "Exam_scores":exam_scores})
df.head(20)
# Out:
#     Hours_studied  Exam_scores
# 0        5.488135    65.789177
# 1        7.151894    94.767733
# 2        6.027634    84.794793
# 3        5.448832    61.881722
# 4        4.236548    86.065262
# 5        6.458941   101.253597
# 6        4.375872    83.667156
# 7        8.917730    92.789402
# 8        9.636628    87.475612
# 9        3.834415    79.716593
# 10       7.917250    85.554482
# 11       5.288949    88.669197
# 12       5.680446    80.484978
# 13       9.255966   106.046222
# 14       0.710361    57.115467
# 15       0.871293    61.422197
# 16       0.202184    51.115920
# 17       8.326198   109.489697
# 18       7.781568    90.176958
# 19       8.700121    97.520501

# %% [markdown]
# # <a id='toc4_'></a>[Step-03 Splitting the data](#toc0_)

# %%
df.columns
# Out:
# Index(['Hours_studied', 'Exam_scores'], dtype='object')

# %%
X = df[["Hours_studied"]]
y = df["Exam_scores"]

X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.2, random_state=32) # shuffle the data

print(len(X_train), len(X_test) , len(y_train), len(y_test))
# Out:
# 80 20 80 20

# %%
X_train
# Out:
#     Hours_studied
# 26       1.433533
# 8        9.636628
# 7        8.917730
# 12       5.680446
# 59       2.444256
# ..            ...
# 62       6.563296
# 54       2.088768
# 5        6.458941
# 43       0.602255
# 87       0.939405
#
# [80 rows x 1 columns]

# %% [markdown]
# # <a id='toc5_'></a>[Step-04 Model Selection](#toc0_)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # <a id='toc6_'></a>[Step-05 Model Prediction](#toc0_)

# %%
y_pred = model_lr.predict(X_test)

# %% [markdown]
# # <a id='toc7_'></a>[Step-06 Model Evaluation](#toc0_)

# %%
mse = mean_squared_error(y_test , y_pred) # difference between Actual and Predicted values
r2 = r2_score(y_test,y_pred)

print(f"mse: {mse:.2f}")
print(f"R_squared: {r2:.2f}")
# Out:
# mse: 81.18
# R_squared: 0.68

# %% [markdown]
# # <a id='toc8_'></a>[Step-07 Create Dataframe](#toc0_)

# %%
dataframe_lr = pd.DataFrame({"Actual_scores":y_test , "Predicted_scores":y_pred})
dataframe_lr.head()
# Out:
#     Actual_scores  Predicted_scores
# 83      85.499118         86.552102
# 53      55.420546         57.145762
# 70      98.140557        100.696143
# 45      82.035548         85.464643
# 44      76.392657         85.271840

# %%
X_test['y_test'] = y_test
X_test['y_pred'] = y_pred
display(X_test)
# Out:
#     Hours_studied     y_test      y_pred
# 83       6.924721  85.499118   86.552102
# 53       1.020448  55.420546   57.145762
# 70       9.764595  98.140557  100.696143
# 45       6.706379  82.035548   85.464643
# 44       6.667667  76.392657   85.271840
# 39       6.818203  93.313082   86.021586
# 22       4.614794  60.369118   75.047466
# 80       3.179832  60.918834   67.900612
# 10       7.917250  85.554482   91.495412
# 0        5.488135  65.789177   79.397158
# 18       7.781568  90.176958   90.819641
# 30       2.645556  81.903370   65.239642
# 73       6.048455  71.977891   82.187843
# 33       5.684339  97.522347   80.374358
# 90       3.185690  75.137036   67.929787
# 4        4.236548  86.065262   73.163606
# 76       2.828070  75.406707   66.148654
# 77       1.201966  45.210513   58.049813
# 12       5.680446  80.484978   80.354965
# 31       7.742337  97.772131   90.624252

# %% [markdown]
# # <a id='toc9_'></a>[Step-09 Data Visualization and Interpretation](#toc0_)

# %%
import matplotlib.pyplot as plt

# Scatter plot of actual test data points
plt.scatter(X_test, y_test, color='blue', label='Actual Data')
# Plotting the regression line
plt.plot(X_test, y_pred, color='red', label='Regression Line', linewidth=2)
# Label the x-axis
plt.xlabel('Hours Studied')
# Label the y-axis
plt.ylabel('Exam Scores')
# Add a legend to the plot
plt.legend()
# Set the title of the plot
plt.title('Simple Linear Regression: Hours Studied vs. Exam Scores')
# Display the plot
plt.show()

# %%
# Extract the slope (coefficient) and intercept from the trained model
slope = model_lr.coef_[0]
intercept = model_lr.intercept_

# Print the slope and intercept with formatting
print(f'Slope (Coefficient): {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
# Out:
# Slope (Coefficient): 4.93
# Intercept: 52.47

# %% [markdown]
# <a id="13"></a>
# <h1 style="background-color:#435420;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 15px 50px;color:#FF9900;">Thankyou</h1>
# <figcaption style="text-align: center;">
#     <strong>
#     </strong>
# </figcaption>
